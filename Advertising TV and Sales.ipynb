# %%
#Linear regression example one variable

# Making the imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# %%
# Preprocessing Input data
data = pd.read_csv('C:/Users/jude1/Downloads/data.csv')
X = data.iloc[:, 1]
Y = data.iloc[:, 4]
plt.scatter(X, Y)
plt.show()

# %%
#BUILDING THE MODEL
m=0
b=0
L=0.00001
epochs=50
n=float(len(X))
for i in range (epochs):
    Y_predict=m*X+b
    PartialDer_m=(-2/n) * sum(X*(Y-Y_predict))
    PartialDer_b=(-2/n) * sum(Y-Y_predict)
    m=m-L*PartialDer_m
    b=b-L*PartialDer_b
    
print(m,b)
# Out:
# 0.08323873042694489 0.0022036485248894387

# %%
#MAKING PREDICTIONS
Y_predict=m*X+b
plt.scatter(X,Y)
plt.plot([min(X),max(X)],[min(Y_predict),max(Y_predict)],color='orange')
plt.show()

# %%
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataxx = pd.read_csv('C:/Users/ADMIN/Documents/TV&Sales.csv')
dataxx
# Out:
#      Unnamed: 0     TV  Sales
# 0             1  230.1   22.1
# 1             2   44.5   10.4
# 2             3   17.2    9.3
# 3             4  151.5   18.5
# 4             5  180.8   12.9
# 5             6    8.7    7.2
# 6             7   57.5   11.8
# 7             8  120.2   13.2
# 8             9    8.6    4.8
# 9            10  199.8   10.6
# 10           11   66.1    8.6
# 11           12  214.7   17.4
# 12           13   23.8    9.2
# 13           14   97.5    9.7
# 14           15  204.1   19.0
# 15           16  195.4   22.4
# 16           17   67.8   12.5
# 17           18  281.4   24.4
# 18           19   69.2   11.3
# 19           20  147.3   14.6
# 20           21  218.4   18.0
# 21           22  237.4   12.5
# 22           23   13.2    5.6
# 23           24  228.3   15.5
# 24           25   62.3    9.7
# 25           26  262.9   12.0
# 26           27  142.9   15.0
# 27           28  240.1   15.9
# 28           29  248.8   18.9
# 29           30   70.6   10.5
# ..          ...    ...    ...
# 170         171   50.0    8.4
# 171         172  164.5   14.5
# 172         173   19.6    7.6
# 173         174  168.4   11.7
# 174         175  222.4   11.5
# 175         176  276.9   27.0
# 176         177  248.4   20.2
# 177         178  170.2   11.7
# 178         179  276.7   11.8
# 179         180  165.6   12.6
# 180         181  156.6   10.5
# 181         182  218.5   12.2
# 182         183   56.2    8.7
# 183         184  287.6   26.2
# 184         185  253.8   17.6
# 185         186  205.0   22.6
# 186         187  139.5   10.3
# 187         188  191.1   17.3
# 188         189  286.0   15.9
# 189         190   18.7    6.7
# 190         191   39.5   10.8
# 191         192   75.5    9.9
# 192         193   17.2    5.9
# 193         194  166.8   19.6
# 194         195  149.7   17.3
# 195         196   38.2    7.6
# 196         197   94.2    9.7
# 197         198  177.0   12.8
# 198         199  283.6   25.5
# 199         200  232.1   13.4
#
# [200 rows x 3 columns]

# %%
### STATSMODELS ###

# create a fitted model
lm1 = smf.ols(formula='Y ~ X', data=dataxx).fit()

# print the coefficients
lm1.params
# Out:
# Intercept    12.351407
# X             0.054693
# dtype: float64

# %%
## SCIKIT-LEARN ###

# create X and y
TVads = ['X']
X = dataxx['TV'].values.reshape(-1,1)
y = dataxx.Sales

# instantiate and fit
lm2 = LinearRegression()
lm2.fit(X, y)

# print the coefficients
print(lm2.intercept_)
print(lm2.coef_)
# Out:
# 7.032593549127693
# [0.04753664]

# %%
sns.pairplot(dataxx)

# %%
# Preprocessing Input data
XX = dataxx.iloc[:, 1]
YY = dataxx.iloc[:, 2]
plt.xlabel('TV')
plt.ylabel('Sales')
plt.scatter(XX, YY)
plt.show()

# %%
Y_predx = lm2.coef_*XX +  lm2.intercept_
#Y_predx = 0.04753664*XX + 7.032593549127693

plt.scatter(XX, YY) 
plt.plot([min(XX), max(XX)], [min(Y_predx), max(Y_predx)], color='orange')  # regression line
plt.show()

# %%
#Y_predx = lm2.coef_*XX +  lm2.intercept_
#0.04753664, 7.032593549127693
Y_predx = 0.04753664*XX + 7.032593549127693

plt.scatter(XX, YY) 
plt.plot([min(XX), max(XX)], [min(Y_predx), max(Y_predx)], color='orange')  # regression line
plt.show()

# %%
m = 0
c = 0


L = 0.00001  # The learning Rate
epochs = 50  # The number of iterations to perform gradient descent

n = float(len(XX)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*XX + c  # The current predicted value of Y
    D_m = (-2/n) * sum(XX * (YY - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(YY - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c

print (m, c)
# Out:
# 0.08323873042694489 0.0022036485248894387

# %%
Y_pred = m*XX + c

plt.scatter(XX, YY) 
plt.plot([min(XX), max(XX)], [min(Y_pred), max(Y_pred)], color='orange')  # regression line
plt.show()
